# %% [markdown]
# ## Init and Run GMM

# %%
# %%javascript
# Jupyter.utils.load_extensions('tdb_ext/main')

# %%
#this sets the backend to jupyter/ipython that (i think) displays
#     images directly. anyway, it prevents the matplotlib framework
#     python error that is my least favorite thing eeeevvvveeeer.
# %matplotlib notebook

import sys
sys.path.append("..")

import gmix_model as gmix
import numpy as np
import tdb as tdb
import tensorflow as tf
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import gmix_sample_mixture as smpl

import os
os.chdir('/Users/azane/GitRepo/spider')

# %%
def remove_nan_rows(x, y):
    #hstack negated isnan checks
    b = ~(np.hstack((np.isnan(x), np.isnan(y))))
    #get rows where all columns are True (not nan)
    b = b.all(axis=1)
    
    return x[b], y[b]

# %%
#read in training and test data
s_x, s_t = gmix.get_xt_from_npz('data/spi_gmix_train.npz', True)
t_x, t_t = gmix.get_xt_from_npz('data/spi_gmix_test.npz', True)

s_x, s_t = remove_nan_rows(s_x, s_t)
t_x, t_t = remove_nan_rows(t_x, t_t)

#TEMP
#expand target dimension so variance can be happy.
scaleOut = 100
s_t *= scaleOut
t_t *= scaleOut

# %% [markdown]
# ### Note on Scaling and Variance Saturation:
#
#    ```GaussianMixtureModel``` needs to handle the variance scaling. The question is, should it scale up from tanh and *then* calculate loss? Or should it keep everything within the tanh range, and then scale up only for outputs?
#
#    If the actual range is large, then it would be more accurate and safer to scale up to the range. But, like in the spider example, if the range is small, so it would actually be safer to keep it at tanh. I think if it can be determined that the tanh range can accurately represent the means and variances, then it's best to keep it there. Otherwise, we might need to expand everything to a middle-man range where loss can be calculated, and then expand to the actual range on formula retrieval.

# %%
#create gmm with data
np.random.seed(np.random.randint(100000))
gmm = gmix.GaussianMixtureModel(s_x, s_t, t_x, t_t,
                               numGaussianComponents=6, hiddenLayerSize=36,
                               learningRate=0.001) #0.005 worked for 2d

# %% [markdown]
# ### Thoughts on Hyperparameters
#
#   * The larger the hidden layers, the more representations of globally best solutions. Thus, a slower training rate can be afforded, as there are more routes out of local minima.
#   * Small hidden layers may require a larger training rate so it can jump out of local minima.
#   * Examining the mixing coefficient averages reveals whether or not some gaussian components are not being used. These should be minimized.
#
# ### Hyperparameters as Variables
#
#    * We need an **intelligent learning rate**. It should make guesses as to whether it's stuck in a local minima, or honing in on a good solution. If it thinks it's stuck, set the learning rate high to jump out, if it's working on a good solution, keep the learning rate low to stay on track.
#       * the loss function needs to scale with the number of samples, otherwise we'll see steeper gradients for for larger sample batches.
#    * The **number of gaussian components** can be selected based on how many are being used, and how much. Having this change during training would require a restructuring of the network, however, and preserving training before restructuring may be impossible.
#       * in other words, this may slow down training considerably, but complexity reduction would vastly increase execution.
#    * It may be worth spawning **a number of networks** working on the same solution. This is a good way to determine whether a **local or global** solution has been found.

# %% [markdown]
# # Train Step

# %%
# %%capture
#d will be a dictionary of evaluated tensors under their standard name.
sessions = 1

sessionIterations = 100
runTimes = sessions*sessionIterations

gmm.learningRate=0.001
gmm.train(iterations=runTimes, testBatchSize=1000,
          trainBatchSize=2500, reportEvery=sessionIterations)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-d2613bd6d23c> in <module>()
#       7 gmm.learningRate=0.001
#       8 gmm.train(iterations=runTimes, testBatchSize=1000,
# ----> 9           trainBatchSize=2500, reportEvery=sessionIterations)
#
# ../gmix_model.pyc in train(self, iterations, testBatchSize, trainBatchSize, reportEvery)
#
# /Users/azane/GitRepo/spider/venv/lib/python2.7/site-packages/tdb/interface.pyc in debug(evals, feed_dict, breakpoints, break_immediately, session)
#      15         global _dbsession
#      16         _dbsession=debug_session.DebugSession(session)
# ---> 17         return _dbsession.run(evals,feed_dict,breakpoints,break_immediately)
#      18
#      19 def s():
#
# /Users/azane/GitRepo/spider/venv/lib/python2.7/site-packages/tdb/debug_session.pyc in run(self, evals, feed_dict, breakpoints, break_immediately)
#      59                         return self._break()
#      60                 else:
# ---> 61                         return self.c()
#      62
#      63         def s(self):
#
# /Users/azane/GitRepo/spider/venv/lib/python2.7/site-packages/tdb/debug_session.pyc in c(self)
#      89                 self.step=i+1
#      90                 if self.step < len(self._exe_order):
# ---> 91                         return self.c()
#      92                 else:
#      93                         return self._finish()
#
# /Users/azane/GitRepo/spider/venv/lib/python2.7/site-packages/tdb/debug_session.pyc in c(self)
#      89                 self.step=i+1
#      90                 if self.step < len(self._exe_order):
# ---> 91                         return self.c()
#      92                 else:
#      93                         return self._finish()
#
# /Users/azane/GitRepo/spider/venv/lib/python2.7/site-packages/tdb/debug_session.pyc in c(self)
#      89                 self.step=i+1
#      90                 if self.step < len(self._exe_order):
# ---> 91                         return self.c()
#      92                 else:
#      93                         return self._finish()
#
# /Users/azane/GitRepo/spider/venv/lib/python2.7/site-packages/tdb/debug_session.pyc in c(self)
#      89                 self.step=i+1
#      90                 if self.step < len(self._exe_order):
# ---> 91                         return self.c()
#      92                 else:
#      93                         return self._finish()
#
# /Users/azane/GitRepo/spider/venv/lib/python2.7/site-packages/tdb/debug_session.pyc in c(self)
#      89                 self.step=i+1
#      90                 if self.step < len(self._exe_order):
# ---> 91                         return self.c()
#      92                 else:
#      93                         return self._finish()
#
# /Users/azane/GitRepo/spider/venv/lib/python2.7/site-packages/tdb/debug_session.pyc in c(self)
#      89                 self.step=i+1
#      90                 if self.step < len(self._exe_order):
# ---> 91                         return self.c()
#      92                 else:
#      93                         return self._finish()
#
# /Users/azane/GitRepo/spider/venv/lib/python2.7/site-packages/tdb/debug_session.pyc in c(self)
#      89                 self.step=i+1
#      90                 if self.step < len(self._exe_order):
# ---> 91                         return self.c()
#      92                 else:
#      93                         return self._finish()
#
# /Users/azane/GitRepo/spider/venv/lib/python2.7/site-packages/tdb/debug_session.pyc in c(self)
#      89                 self.step=i+1
#      90                 if self.step < len(self._exe_order):
# ---> 91                         return self.c()
#      92                 else:
#      93                         return self._finish()
#
# /Users/azane/GitRepo/spider/venv/lib/python2.7/site-packages/tdb/debug_session.pyc in c(self)
#      85
#      86                 self.state = RUNNING
# ---> 87                 self._eval(node)
#      88                 # increment to next node
#      89                 self.step=i+1
#
# /Users/azane/GitRepo/spider/venv/lib/python2.7/site-packages/tdb/debug_session.pyc in _eval(self, node)
#     165                         # All Tensors MUST be in the cache.
#     166                         feed_dict=dict((t,self._cache[t.name]) for t in node.inputs)
# --> 167                         node.run(feed_dict) # this will populate self._cache on its own
#     168                 else: # is a TensorFlow node
#     169                         if isinstance(node,tf.Tensor):
#
# /Users/azane/GitRepo/spider/venv/lib/python2.7/site-packages/tdb/plot_op.pyc in run(self, feed_dict)
#      46
#      47         def run(self, feed_dict):
# ---> 48                 results=super(PlotOp, self).run(feed_dict)
#      49                 # send the image over
#      50                 if app.is_notebook():
#
# /Users/azane/GitRepo/spider/venv/lib/python2.7/site-packages/tdb/python_op.pyc in run(self, feed_dict)
#      48                 #pdb.set_trace()
#      49                 args=tuple(feed_dict[i] for i in self.inputs)
# ---> 50                 results=self.fn(self, *args)
#      51                 self.cache_values(results)
#      52                 return results
#
# ../gmix_tdbviz.pyc in watch_biases(ctx, b)
#
# ../gmix_tdbviz.pyc in watch1graph(ctx, y, yLabel, title)
#
# /Users/azane/GitRepo/spider/venv/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3152         ax.hold(hold)
#    3153     try:
# -> 3154         ret = ax.plot(*args, **kwargs)
#    3155     finally:
#    3156         ax.hold(washold)
#
# TypeError: plot() takes at least 3 arguments (2 given)

# %% [markdown]
# # Visualization

# %%
def scale(x, y, low, high, i=-1):
    """takes two 2d arrays, but only checks the last y column."""
    indices = np.where((y[:,i] >= low) & (y[:,i] <= high))
    return x[indices], y[indices]

# %%
def init4d(x, y, xCols=[0,1,-1], yLow=None, yHigh=None):
    """Takes two 2d arrays, but only graphs the 
        first x columns in xCols, and the last y."""
    
    #TODO enable this to take two sets of x and y, 
    #    so they can be compared easily.
    
    assert y.ndim == 2
    assert y.shape[1] == 1
    assert x.ndim == 2
    assert len(xCols) == 3
    assert x.shape[0] >= len(xCols)
    
    if (yLow is not None) and (yHigh is not None):
        #TODO allow the output to be culled by only high or only low
        #exclude points outside of low/high range
        x, y = scale(x, y, yLow, yHigh)
    
    x = np.squeeze(x.transpose())
    y = np.squeeze(y[:,0])
    
    assert y.ndim == 1
    assert x.ndim == 2
    
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d') #create subplot in figure.
    
    #set the color map to the output dimension.
    scatPlot = ax.scatter(
                            x[xCols[0]],
                            x[xCols[1]],
                            x[xCols[2]],
                        c=y) #create plot
    
    ax.set_xlabel("x1")
    ax.set_ylabel("x2")
    ax.set_zlabel("x3")
    
    #add colorbar label
    cb = fig.colorbar(scatPlot)
    cb.set_label("y")
    
    return fig, scatPlot

# %%
#m, v, u = gmm.get_xmvu()

#play with stuff
#v = np.ones((t_t.shape))*0.01

x, y = smpl.sample_mixture(t_x, m, v, u) #set to gmm sample

t_x_ = np.copy(t_x)
t_t_ = np.copy(t_t)

#cull data to a set number of points.
lim = 1000
if x.shape[0] > lim:
    randRows = np.random.randint(x.shape[0],size=lim)
    x = x[randRows]
    y = y[randRows]
if t_x_.shape[0] > lim:
    randRows = np.random.randint(t_x_.shape[0],size=lim)
    t_x_ = t_x_[randRows]
    t_t_ = t_t_[randRows]

xCols = [1,2,-1]
yLow = -0.022*scaleOut
yHigh = 0.022*scaleOut

init4d(x, y, xCols=xCols, yLow=yLow, yHigh=yHigh)
init4d(t_x_, t_t_, xCols=xCols, yLow=yLow, yHigh=yHigh)
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x14004c790>,
#  <mpl_toolkits.mplot3d.art3d.Path3DCollection at 0x1403b6c10>)

# %% [markdown]
# ## Debugging

# %%
evalStr = [
    'calc_agg_grad_w1',
    'calc_agg_grad_b1',
    'calc_agg_grad_w2',
    'calc_agg_grad_b2',
    'calc_agg_grad_w3',
    'calc_agg_grad_b3',

    'v',
    'm',
    
    'w1',
    'w2',
    'w3',
    'b1',
    'b2',
    'b3'
    ]
d = gmm.get_evals(evalStr)

# %%
#save parameters of trained network for use by the spider brain.
#TODO fix variance scaling, otherwise,
#   the spider will need to rescale the output.
np.savez('spi_gmm_wb.npz',
         w1=d['w1'],
         w2=d['w2'],
         w3=d['w3'],
         b1=d['b1'],
         b2=d['b2'],
         b3=d['b3']
        )

# %%
#%%capture
print 'calc_agg_grad_w1'
print d['calc_agg_grad_w1']
print 'calc_agg_grad_b1'
print d['calc_agg_grad_b1']
print 'calc_agg_grad_w2'
print d['calc_agg_grad_w2']
print 'calc_agg_grad_b2'
print d['calc_agg_grad_b2']
print 'calc_agg_grad_w3'
print d['calc_agg_grad_w3']
print 'calc_agg_grad_b3'
print d['calc_agg_grad_b3']
# Out:
# calc_agg_grad_w1
# [[  2.09468359e-04   4.14281618e-04   5.27655648e-04   7.48236664e-04
#    -2.34956315e-04  -1.18464639e-04  -8.26360774e-05  -6.55672862e-04
#     1.36846458e-04  -5.55213774e-04  -4.31885332e-04   1.76192843e-04
#     2.36887689e-04  -1.36433127e-05  -4.31256281e-04  -1.90959516e-04
#    -1.68304687e-04  -4.50003048e-04  -1.65866630e-04  -3.17795530e-05
#    -1.95469911e-04  -8.66092101e-04  -5.29632816e-05   1.02981685e-04
#    -1.79681476e-04  -1.76443689e-04   4.31158696e-04   9.80991390e-05
#    -2.66002062e-05  -6.14518998e-04   9.17837606e-05  -3.82452825e-04
#    -4.53689572e-04  -4.01022378e-04   1.92655090e-04   6.60221151e-04
#    -5.01662202e-04  -9.06291767e-04   3.24452558e-04  -4.49746381e-04
#    -9.86766463e-05   8.86562048e-05  -1.96746914e-04  -1.72772794e-04
#    -2.53088627e-04  -1.00997067e-03   1.53493202e-05  -3.74595606e-04
#    -8.61312656e-05]
#  [ -5.81048196e-04   4.64074446e-06  -1.48540683e-04   2.50077603e-04
#    -1.19908014e-04  -7.80142553e-04   3.38238315e-04  -3.34429002e-04
#    -2.93583900e-04  -2.71155295e-04   1.64735844e-04   4.21757082e-04
#     1.44999562e-04  -8.02275754e-05  -7.56526861e-05  -1.29695953e-04
#    -5.72916106e-05   5.60097164e-04  -3.97786294e-04   9.02322470e-04
#     8.16808315e-04   4.64341341e-04   2.03395146e-04   4.40602336e-04
#    -2.66139949e-04   2.99090461e-04  -4.80525981e-04  -2.70399643e-04
#     3.21216474e-04  -4.29556705e-04   4.27127088e-04  -6.90489134e-04
#     4.05992090e-04   4.79539158e-05   6.86797488e-04  -2.59764402e-05
#     6.19375147e-04   3.63091705e-04   3.83999395e-05   2.64589384e-04
#     7.27538369e-04   5.13969222e-04   2.31974391e-05  -4.81183495e-04
#     1.32321817e-04  -1.73681154e-04   4.01193422e-04   1.51967062e-04
#    -6.75283838e-04]
#  [  7.79522758e-04   1.99967675e-04   5.79633343e-04   1.21247504e-04
#     3.32007447e-04   3.42910324e-04  -7.27334584e-04  -2.80376316e-05
#     5.28392382e-04  -2.62676156e-04  -4.14312846e-04  -1.90443505e-04
#     1.61253542e-04  -2.45217234e-04  -7.41418335e-04  -2.78627722e-05
#    -1.74302520e-04  -5.98707935e-04  -2.36344844e-04  -3.71089816e-04
#    -2.84100766e-04  -1.10186683e-03   7.68315476e-06  -4.64242301e-04
#     3.09385912e-04   8.32232836e-05   1.30745140e-03   6.70596492e-04
#    -3.55688622e-04  -1.07812390e-04  -2.97437538e-04   3.48124537e-04
#    -4.89441096e-04   2.30544145e-04  -3.11787851e-04   2.37930362e-04
#    -3.00360669e-04  -9.75321571e-04  -5.34706596e-05  -4.55961475e-04
#    -3.33099975e-04   5.29698038e-04  -2.72291567e-04  -1.18348813e-04
#     4.84878183e-06  -4.62092721e-04  -2.51436461e-04  -7.35350011e-04
#     8.80377193e-04]
#  [ -3.12734948e-04  -3.55230994e-04  -3.14712437e-04  -5.02035371e-04
#    -2.96700833e-04  -2.84658658e-04   4.42201796e-04  -2.72065256e-04
#    -2.99165462e-04   1.09836445e-04  -2.22683393e-05  -3.35085788e-04
#    -1.55822170e-04   3.41612671e-04   6.28813286e-04  -2.73006415e-04
#     4.08723310e-04   4.49029671e-04   3.48420115e-04   2.11884726e-05
#    -1.91445084e-04   1.95984132e-04  -4.39390657e-04   7.81422423e-04
#    -4.46771810e-05  -4.79991868e-04  -4.50223248e-04  -1.23458565e-03
#     7.51766027e-04   9.23336775e-05  -5.21559326e-04  -1.38732794e-04
#     2.95837846e-04  -3.91424721e-04   3.33974458e-04   6.54570249e-05
#     2.78138003e-04   6.41457678e-04  -3.09177180e-04   4.51888889e-04
#    -1.40073374e-04  -3.44780245e-04   1.50013540e-04  -5.73344842e-05
#    -4.74800589e-04   3.75994947e-04   5.93317149e-04   1.01193227e-03
#    -2.01618765e-04]
#  [  5.40751753e-05  -2.61894660e-04  -3.78949858e-06  -4.81783529e-04
#     1.80609248e-04  -1.55171816e-04  -1.61687916e-04   7.75906519e-05
#     8.71588054e-05   1.81641430e-04   1.72815649e-04  -4.33547975e-04
#    -4.40980104e-04  -3.23442539e-04  -5.50708355e-05  -2.53392209e-04
#    -5.74139131e-06  -1.75928421e-04  -2.17297536e-04   8.48643231e-06
#    -5.21482116e-06  -4.83142649e-04   6.48075147e-05   3.46219138e-04
#     5.35715313e-04   1.04339597e-04   4.97440575e-04  -2.90951342e-04
#    -8.41000874e-05  -5.01313305e-04  -4.98645677e-05   2.54956714e-04
#    -1.40137068e-04   2.41951828e-04   1.90976294e-04   3.83405888e-04
#     1.77902111e-04  -2.62438029e-04  -2.47209420e-04   3.12357064e-04
#     5.30156030e-05   4.00970806e-04  -2.68869713e-04  -5.61576220e-04
#     2.03273303e-04  -1.52017194e-04  -3.85331768e-05   1.74411369e-04
#     5.84789144e-04]]
# calc_agg_grad_b1
# [  5.40363661e-04   3.17238708e-04   5.16248925e-04   3.12213378e-04
#    3.02549539e-04   1.14700140e-03  -1.04810600e-03   4.52808104e-04
#    5.69981115e-04  -4.89244230e-05  -5.38115273e-04  -9.64298033e-06
#    3.84016457e-05  -1.53811401e-04  -5.91697113e-04   5.41533111e-04
#    2.32561397e-05  -1.10688061e-03   3.31178686e-04  -1.27142307e-03
#   -6.13953453e-04  -7.44893099e-04  -7.87692188e-05  -1.17012754e-03
#    2.85289920e-04  -1.17681840e-04   7.36202288e-04   1.43718347e-03
#   -9.42316721e-04   2.92683981e-04   3.49047605e-06   6.65162399e-04
#   -9.69064597e-04   1.33297362e-04  -9.44250380e-04   5.07658464e-04
#   -1.22068380e-03  -8.79144354e-04   4.07873013e-04  -9.53563896e-04
#   -7.49277067e-04  -5.20351226e-04  -2.40906855e-04   7.20193202e-04
#    1.24491387e-04  -2.50378577e-07  -9.94398841e-04  -1.16318872e-03
#    7.32190209e-04]
# calc_agg_grad_w2
# [[ -7.87234312e-05  -2.41251109e-04   3.85385283e-06 ...,   1.53909772e-04
#     3.44694090e-05  -6.85574423e-06]
#  [ -3.76034186e-05  -1.04135586e-04   3.07805421e-05 ...,   1.13970505e-04
#    -2.31892282e-05  -2.33099126e-05]
#  [  4.30732371e-06  -3.71662783e-04   1.86573408e-04 ...,   1.56589696e-04
#    -8.70978984e-05   8.20995556e-05]
#  ...,
#  [  5.54480248e-05  -1.55857240e-04   1.26508661e-04 ...,   2.19555614e-06
#    -4.85713645e-05   3.64394509e-05]
#  [ -7.79723632e-05   9.88684696e-05  -1.39678625e-04 ...,   7.93155778e-06
#     7.33449560e-05  -2.63573620e-05]
#  [ -6.68399080e-05   3.86471183e-05  -2.16577228e-05 ...,  -1.86313391e-05
#    -3.96714313e-05  -1.41896371e-05]]
# calc_agg_grad_b2
# [  5.12589584e-04   1.47773023e-03  -3.85221123e-04  -3.52037023e-04
#   -8.85897840e-04  -1.68220780e-04  -8.82249849e-04   1.68571234e-04
#    1.16295810e-03   3.99330107e-04   8.83437518e-04   1.36370363e-04
#    8.23419774e-04   9.18029109e-04  -4.26973158e-04   3.05607420e-04
#   -4.62973927e-04  -5.09765872e-04  -6.26525900e-04   1.73704582e-04
#   -1.56739072e-04  -3.88502347e-04  -6.08033151e-04   2.15421605e-04
#   -2.89139833e-04  -2.97318154e-04  -7.40121992e-04   8.30513949e-04
#    6.76173484e-04   3.42954270e-04  -2.51359801e-04   4.43070370e-04
#   -3.32845259e-04  -3.47893423e-04  -3.20743333e-04   6.44538231e-05
#   -1.28016202e-03  -1.50842941e-03  -7.30402360e-04   6.40656101e-04
#   -6.62218838e-04   9.05600726e-04   4.84265387e-04  -1.73686494e-04
#    5.33003069e-04  -2.98549159e-04  -7.05115322e-04   3.18543403e-04
#   -3.31918680e-04]
# calc_agg_grad_w3
# [[  3.73394369e-06  -5.46243928e-06   2.25343865e-05  -1.27500016e-06
#    -4.30797154e-05   1.07133210e-05   1.28355105e-05   2.86362374e-05
#    -2.68823729e-04   1.51435052e-05   1.48938474e-04   2.43690345e-04
#    -1.24259124e-04  -3.72515526e-04  -1.02243539e-05]
#  [  4.63965853e-06  -9.74278191e-06   9.01970270e-06  -1.79099754e-06
#    -2.58138516e-05   2.55106147e-06   2.11371935e-05  -1.11506975e-04
#    -2.55478430e-04  -3.03586745e-07  -3.92626089e-06  -4.99524576e-05
#    -6.38230849e-05  -1.65733902e-04  -1.16177558e-04]
#  [ -3.25057663e-05   1.31681336e-05  -1.80057941e-05   9.57989141e-06
#     2.72973393e-05   3.83941256e-07   8.21717805e-08   1.81343581e-04
#     1.86079706e-04  -2.74237336e-05  -3.13457313e-05   4.68503102e-04
#    -7.66862740e-06  -2.00937196e-04   7.37377559e-05]
#  [  1.85470344e-06   1.26010209e-05  -1.13536007e-05  -8.88669192e-08
#     3.50133705e-05  -1.29012033e-05  -2.51253605e-05  -1.11432826e-04
#     1.61843709e-04  -1.43519046e-05  -5.51465528e-05  -7.72105705e-05
#     9.58463716e-05   2.90800264e-04   9.10965828e-05]
#  [  7.32589160e-06  -7.33969136e-06   2.53155176e-05  -1.46988000e-07
#    -3.94429153e-05   4.67268001e-06   9.61555725e-06   9.06297355e-05
#    -1.78982824e-04   6.94359333e-05   1.54658250e-04   1.19757773e-04
#    -1.21682504e-04  -2.30281235e-04   7.06660940e-05]
#  [ -2.12070408e-05   1.88641661e-05  -8.24614108e-06  -4.19155640e-06
#     2.24763589e-05  -1.87428686e-05   1.10471246e-05  -1.09611358e-03
#     2.34235020e-04   1.33085865e-04   4.55980626e-06   3.92481190e-04
#     1.03968036e-04  -4.52577151e-05   1.14727794e-04]
#  [  1.54008521e-05   2.22414656e-06   3.42556668e-05  -2.09717246e-06
#    -3.50271475e-05  -1.18729558e-05  -2.88337560e-06  -6.81987032e-04
#    -8.19494835e-06   1.36714923e-04   1.43547077e-04  -4.49480140e-05
#    -5.50687982e-05  -1.09403290e-05   1.08925269e-04]
#  [  9.84969665e-06  -1.13493788e-05   1.00364705e-05  -2.80601762e-06
#    -3.55911070e-05   2.36176356e-06   2.74986087e-05  -3.31617863e-04
#    -1.15978590e-04   1.10061643e-04   7.98796827e-05   7.26363942e-05
#    -6.56911579e-05  -2.58208049e-04  -7.90091726e-05]
#  [ -9.88303145e-06   1.04712653e-05  -6.95540530e-06   6.21870686e-06
#     2.16259468e-05  -1.31100533e-05  -8.36742583e-06   4.00911194e-05
#     3.36967641e-04  -6.49108333e-05  -4.96840985e-05  -2.73637124e-04
#     1.18899152e-04   3.13967321e-04  -1.42224235e-04]
#  [ -2.88839828e-06   4.74687613e-06  -5.41747977e-06   7.74198270e-06
#     3.05541507e-05  -1.97115611e-07  -3.45400222e-05   5.94417506e-04
#     2.49650708e-04  -9.03804757e-05  -4.70533523e-05   9.92178138e-06
#     4.19426215e-06   1.67091071e-04   1.11885478e-04]
#  [ -2.29342604e-05   2.22197086e-05  -7.70439692e-06   1.85054023e-06
#     3.45146873e-05   1.40098177e-06  -2.93472913e-05  -2.17090463e-04
#     1.14335802e-04  -8.67554409e-05  -1.41522851e-05   2.26923803e-04
#     3.17769991e-05  -8.71294833e-06   1.74078887e-04]
#  [ -8.42182089e-06   1.93621308e-05  -1.11997097e-05  -6.70162126e-06
#     3.46270499e-05  -1.07770938e-05  -1.68888309e-05  -7.59586343e-04
#     1.25220424e-04   5.30098914e-05  -8.97623795e-06   1.78011498e-04
#     1.54002017e-04   1.20988319e-04   1.07842519e-04]
#  [ -8.25796542e-06   1.65451056e-05   4.87634452e-06  -8.36060917e-06
#     1.24422613e-05  -1.75135046e-05   2.68334276e-07  -1.88358291e-03
#     3.20186926e-04   1.67118342e-04   8.01201022e-05  -9.60462057e-05
#     6.44289612e-05   8.66402188e-05   9.28377485e-05]
#  [  2.30736805e-05  -6.60220985e-06   1.76373087e-05  -6.70688678e-06
#    -2.21546343e-05   7.07640038e-06  -1.23237078e-05  -4.22197627e-04
#    -9.18835940e-05   1.25797218e-04   4.89889608e-05   1.23382400e-04
#    -1.02911163e-05  -6.08253285e-05   1.20321143e-04]
#  [  2.29077227e-06   3.28092756e-06  -1.46988941e-05   2.99642602e-06
#     3.36240737e-05  -9.25280801e-06  -1.82405074e-05   3.27548551e-05
#     3.55910714e-04   6.00285239e-05  -1.09661400e-04  -2.02031588e-04
#     1.14255308e-04   3.37712612e-04   1.88068577e-06]
#  [ -5.15245438e-06   3.73598755e-06  -1.60079107e-05   1.45128718e-06
#    -4.88259957e-06   1.92338866e-05   1.62176718e-06   9.32460767e-04
#    -3.45134264e-04  -2.29004436e-04  -5.36703992e-05   1.76057831e-04
#     1.17144066e-06  -1.08835899e-04  -1.12880683e-04]
#  [  1.59270553e-06  -7.55379051e-06  -3.49193033e-06  -8.00095677e-06
#    -7.79428592e-06  -7.61747060e-06   3.28658061e-05   1.39783384e-04
#    -1.17343319e-04   3.88982335e-05  -7.73483771e-06  -2.00715280e-04
#    -3.70956259e-05  -5.28665660e-05  -1.38777963e-04]
#  [ -2.45614160e-06   1.14090326e-05   1.97051213e-06  -1.09915809e-05
#    -4.46220355e-07  -2.31535760e-05   2.36679462e-05  -1.34040322e-03
#     4.94656888e-05   1.46247374e-04   2.02158517e-05   2.80978187e-04
#     8.76476988e-05   2.96414487e-06   7.93453546e-06]
#  [  6.05652394e-06  -1.79348826e-05   1.85617228e-05   7.52192955e-06
#    -4.24624013e-05   8.43504768e-06   1.98221660e-05   3.32210533e-04
#    -1.69093648e-04   8.06263852e-05   6.99165248e-05  -6.09074050e-05
#    -1.06208419e-04  -2.51558435e-04  -6.82471946e-05]
#  [ -9.87244221e-06   1.92991635e-07  -1.43591287e-05   8.89146213e-06
#     5.92507104e-06   1.13657316e-05  -2.14370107e-06   1.73485576e-04
#     2.26067088e-04  -5.09845013e-05  -4.10910870e-05  -1.13088754e-04
#     1.85110657e-05   6.59980215e-05  -1.56587499e-04]
#  [  4.69537463e-06  -2.17085426e-06   3.18511084e-05   8.33633021e-06
#    -3.10932592e-05   8.34203092e-06  -1.99607002e-05  -1.35309638e-05
#    -6.90655143e-05  -3.14882382e-05   1.41379947e-04   2.54137529e-04
#    -1.43693032e-04  -2.42316339e-04   2.70278862e-04]
#  [ -4.31683156e-06   8.32406295e-06  -8.94889490e-06   7.48133914e-07
#     3.76414609e-05  -1.08782433e-05  -2.25697149e-05   4.30736633e-04
#     1.58950919e-04  -1.04893246e-04  -1.16918563e-04  -1.52621127e-04
#     6.31360308e-05   2.99934327e-04   8.58262210e-05]
#  [  4.80262543e-06  -1.18009511e-05  -1.78146965e-05   8.79068557e-06
#     1.92714961e-05   1.03805996e-06  -4.28725389e-06   6.90014509e-04
#     1.84350763e-04   8.60530563e-05  -1.17159485e-04  -4.16666126e-06
#     2.00923978e-06   1.54646259e-04  -6.26022347e-06]
#  [  2.74369722e-05  -2.48894030e-05  -2.54298948e-06  -1.01974965e-05
#    -1.99880560e-05   2.46855848e-06   2.77124309e-05   7.97968300e-04
#    -1.50983498e-04   4.41493830e-05  -3.73035546e-05  -2.58789980e-04
#    -6.25677567e-05   8.47595657e-05  -2.88073294e-04]
#  [  1.48272784e-05  -5.10104201e-06   1.21668490e-05  -7.03218348e-06
#    -3.15758480e-05   2.08952270e-06   1.46254006e-05  -4.09358734e-04
#    -1.56024427e-04   1.08734319e-04   9.30437600e-05   9.29160306e-05
#    -4.62653261e-05  -1.97556161e-04   3.57487515e-05]
#  [ -1.01881651e-05   1.21850662e-05  -4.89987860e-06  -4.54319115e-06
#     2.49718523e-05  -2.26890315e-05   5.16334057e-06  -1.40267657e-03
#     3.03835026e-04   2.25911455e-04  -6.56690463e-05   7.33546549e-05
#     1.46558523e-04   9.39093443e-05   3.84688392e-05]
#  [ -1.88376653e-05   1.97747295e-06  -8.43066573e-06   2.14255306e-06
#     1.04591436e-05   1.26861914e-05   2.93689739e-09   6.59397861e-04
#    -1.90836436e-04  -7.35569047e-05  -1.22625306e-05   2.56177940e-04
#    -1.10748997e-05  -3.30968323e-04  -4.32781917e-06]
#  [ -1.10794726e-05   6.03923809e-06  -2.11671522e-05  -2.82696902e-07
#     2.20597231e-05  -1.53900546e-05   1.98204052e-05  -3.70416587e-04
#     1.43948942e-04   1.11270499e-04  -1.07043241e-04   1.08457054e-04
#     1.06919804e-04   5.49325814e-05  -1.19450939e-04]
#  [  2.61151240e-06  -1.26137309e-06  -5.42009593e-06  -9.38638641e-06
#    -1.15154762e-05   3.22277242e-06   2.17490615e-05  -4.59617673e-04
#    -1.30779081e-04   2.70554610e-05   6.22537846e-05  -4.39834221e-05
#    -6.69064830e-05  -9.30986280e-05  -1.03902770e-04]
#  [ -3.24781504e-05   1.87286314e-05  -1.36015442e-05   1.18449145e-06
#     2.69201901e-05  -9.17038233e-06   8.41681867e-06  -4.70849453e-04
#     2.48199300e-04  -1.28852640e-04   5.90719392e-05   1.39550510e-04
#     6.51048049e-06  -1.65203470e-04  -6.28352427e-05]
#  [ -2.94296547e-06  -1.11559357e-05  -9.37599680e-07   1.42972772e-06
#    -9.01613748e-06   4.91123774e-06   1.77116835e-05   1.10282621e-03
#    -2.60354485e-04  -7.81799172e-05  -6.98885342e-05   1.10958528e-04
#    -8.75346905e-06  -2.23610477e-04  -1.45407423e-04]
#  [  1.09187704e-05  -1.84087203e-05  -1.44515443e-05  -5.53789641e-06
#    -2.66944397e-07   1.08743398e-05   1.68720253e-05   7.71103951e-04
#    -3.45216045e-04   9.45019565e-05  -6.16765319e-05   2.16880842e-04
#     3.28871247e-05  -2.32718201e-04  -5.84619520e-05]
#  [  1.95842586e-06   1.91938193e-06  -1.48424788e-05  -2.86520662e-06
#     2.21540413e-05  -3.97538133e-06  -4.34878939e-06  -2.14833664e-04
#     2.86502764e-04   3.47557070e-05  -1.27877516e-04  -2.64951523e-04
#     8.94380064e-05   2.61507172e-04  -1.06412830e-04]
#  [ -1.53068663e-06  -3.73450553e-06   1.10906612e-05  -1.21320977e-06
#    -2.78676034e-05   6.78965080e-06   1.64657067e-05   1.53021174e-04
#    -4.32458415e-04  -6.75019764e-05   7.64157448e-05   2.49938777e-04
#    -1.22621830e-04  -3.24064284e-04  -1.06708849e-05]
#  [ -2.09513310e-05   2.80413478e-05  -1.40347411e-05   1.09076188e-06
#     2.90557200e-05   2.15349971e-07  -2.34171948e-05  -7.82004616e-04
#     2.78490712e-04  -1.34206493e-04   2.19608464e-05   7.60390467e-05
#     4.67342397e-05   1.27903942e-04   1.53022163e-04]
#  [  1.45790400e-05  -1.82452914e-05   1.73124408e-06   1.96266342e-06
#    -1.50613814e-05   1.07012729e-05   4.33244259e-06   8.86099355e-04
#    -8.42097070e-05  -1.44905629e-04  -5.91416792e-05  -4.33151872e-04
#    -1.37919604e-04   8.76143604e-05  -2.54553132e-04]
#  [ -1.46152288e-05   1.88711829e-06  -1.62226806e-05   1.37481911e-05
#     1.50791939e-05   2.34041272e-05  -2.32807088e-05   1.09271775e-03
#    -1.18972443e-04  -1.88660764e-04  -3.53810756e-05   1.72587606e-04
#     6.57074088e-06  -1.62390439e-04  -3.49102015e-06]
#  [ -4.44307943e-06  -1.46986349e-05  -2.71361405e-05   2.04203275e-06
#     2.60585130e-05   3.79017297e-06   1.43871321e-05   1.65379816e-03
#    -6.41145671e-05  -9.59062236e-05  -2.30865960e-04  -1.14087758e-04
#     5.45210532e-05   6.53291791e-05  -2.21465089e-04]
#  [ -6.59038960e-06   1.67690177e-05  -1.54076370e-05  -6.14078999e-06
#     3.67183056e-05  -1.31168317e-05  -1.22317615e-05  -6.13591284e-04
#     1.80273535e-04   7.51471725e-06  -6.78863726e-05   6.10567731e-05
#     1.60683805e-04   2.19984198e-04   1.86506338e-06]
#  [ -2.29520501e-05  -2.97274573e-06  -1.89902785e-05   6.42617033e-06
#     1.48346498e-05   1.49979696e-05   8.65632865e-06   5.83493733e-04
#    -2.14461361e-05  -4.46860577e-05  -2.88326319e-05   2.74655235e-04
#    -9.84956660e-06  -3.03481211e-04  -8.57183568e-06]
#  [ -1.19378237e-05  -4.87362968e-06  -1.59624451e-05   3.26031113e-07
#     2.06297682e-06   6.25714347e-06   2.41278012e-05   1.01962592e-03
#    -1.44242455e-04  -9.62803169e-05  -7.73056763e-06   1.04238236e-04
#    -8.84941765e-05  -1.22090525e-04  -9.71960326e-05]
#  [  1.32906107e-05   1.33162584e-05   1.20171235e-05  -9.42919451e-06
#    -3.19187566e-05  -1.16074834e-05   1.43314719e-05  -1.45638664e-03
#    -2.62002519e-04   9.58764940e-05   1.63208300e-04   1.41727898e-04
#    -4.38619172e-05  -3.44557629e-05   9.33164119e-05]
#  [ -2.32698562e-06   1.09902030e-05  -1.11082782e-05  -5.36136724e-07
#     2.93800294e-05  -1.32500600e-05  -1.31488368e-05  -9.64237959e-04
#     3.35018383e-04   1.52268272e-04  -1.00050114e-04  -2.38262815e-04
#     1.43271143e-04   2.54550803e-04   4.62106573e-06]
#  [  7.79650327e-06  -2.70186192e-05   1.04260780e-05   1.75541336e-05
#    -2.59595599e-05   3.68181427e-05  -1.96166657e-05   1.66749978e-03
#    -2.30230042e-04  -7.33742927e-05  -6.73645700e-05   3.26610166e-06
#    -1.16992698e-04  -1.85113691e-04   2.48609413e-05]
#  [ -3.63708659e-06   1.94932054e-05  -1.69846953e-05  -8.73112003e-06
#     3.47436326e-05  -1.07004662e-05  -1.41834262e-05  -9.66304680e-04
#     2.58642482e-04   3.23689965e-05  -4.03899285e-05  -3.21489024e-05
#     1.42544188e-04   2.65436713e-04   5.48386051e-05]
#  [  3.67953248e-06   1.17594709e-06  -1.15244866e-05   1.20241498e-06
#     2.41438647e-05  -4.86404451e-06  -1.38132345e-05  -6.81752063e-05
#     3.81213351e-04   6.88575092e-05  -9.23739426e-05  -2.94211088e-04
#     9.44901258e-05   3.32469383e-04   1.08450113e-05]
#  [  1.85997706e-05  -3.90894286e-07   2.21803675e-05  -1.81199903e-05
#    -3.43987631e-05  -1.13669785e-05   2.34963900e-05  -1.03154092e-03
#    -2.19604641e-04   1.68512677e-04   8.72258533e-05   1.62943470e-04
#    -4.86384261e-06  -1.54492605e-04   2.25137719e-05]
#  [ -7.71308805e-06   2.61259265e-05  -2.61827790e-05  -8.29332657e-06
#     3.12056618e-05  -9.88447255e-07  -1.41539258e-05  -1.01587642e-03
#     2.12013561e-04  -3.03953288e-06   6.28241396e-05  -3.13713754e-05
#     5.39584289e-05   3.77449178e-04   1.39590684e-05]
#  [  3.36516769e-06  -1.17878653e-05   1.19155466e-05  -1.65736287e-06
#    -3.61108541e-05   1.38603882e-05   2.04149983e-05   7.13582325e-04
#    -3.55321536e-04  -4.02030309e-05   1.28216503e-04   3.18305771e-04
#    -1.94647742e-04  -3.69210087e-04  -3.66983622e-05]]
# calc_agg_grad_b3
# [ -1.37935203e-05   3.93171977e-05   4.95614995e-06  -1.96972123e-05
#    1.35180935e-05  -2.63908751e-05   2.09011023e-06  -2.85589742e-03
#    3.26714653e-04   1.38364354e-04   1.63301607e-04  -3.21926564e-05
#    1.11660782e-04   2.31173748e-04   5.91182761e-05]

# %%
print d['v']
print np.mean(d['v'])
# Out:
# [[ 2.08468151]
#  [ 2.25437617]
#  [ 1.75722206]
#  ...,
#  [ 0.72610533]
#  [ 0.6517967 ]
#  [ 0.70770741]]
# 2.04403

# %%
print np.mean(d['m'], 0)
# Out:
# [ 0.1482784   0.15293837  0.1184567   0.12944858  0.1170379   0.17114237
#   0.16269767]

# %% [markdown]
# ### Note on Mixing Coefficients
# I have yet to see a mixing coefficient much below .1. This tells me something may be awry, and may be/is the cause of many stray points.
