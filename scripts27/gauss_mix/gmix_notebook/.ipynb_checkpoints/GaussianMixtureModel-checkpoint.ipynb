# %% [markdown]
# ## Init and Run GMM

# %%
# %%javascript
# Jupyter.utils.load_extensions('tdb_ext/main')

# %%
#this sets the backend to jupyter/ipython that (i think) displays
#     images directly. anyway, it prevents the matplotlib framework
#     python error that is my least favorite thing eeeevvvveeeer.
# %matplotlib notebook

import sys
sys.path.append("..")

import gmix_model as gmix
import numpy as np
import tdb as tdb
import tensorflow as tf
import matplotlib.pyplot as plt

import os
os.chdir('/Users/azane/GitRepo/spider')

# %%
#read in training and test data
s_x, s_t = gmix.get_xt_from_npz('data/toy_train.npz')
t_x, t_t = gmix.get_xt_from_npz('data/toy_train.npz')

# %%
#create gmm with data
gmm = gmix.GaussianMixtureModel(s_x, s_t, t_x, t_t,
                               numGaussianComponents=3, hiddenLayerSize=5,
                               learningRate=0.01)

# %%
# %%capture
#d will be a dictionary of evaluated tensors under their standard name.
runTimes = 10
d = gmm.train(iterations=runTimes, testBatchSize=500,
          trainBatchSize=300, reportEvery=runTimes)

# %% [markdown]
# ## Debugging

# %%
#%%capture
print 'grad_w1'
print d['grad_w1']
print 'grad_b1'
print d['grad_b1']
print 'grad_w2'
print d['grad_w2']
print 'grad_b2'
print d['grad_b2']
print 'grad_w3'
print d['grad_w3']
print 'grad_b3'
print d['grad_b3']
# Out:
# grad_w1
# [[ 12.7801609    3.68335438  -2.59120226 -16.22013283  -8.71039581]]
# grad_b1
# [ 173.12640381    4.27630615  -54.90126419 -198.35990906 -139.7172699 ]
# grad_w2
# [[ -1.55907607   6.98854446  33.63178253  -1.16968191  14.64447975]
#  [ -1.62870347   6.55757141  37.08070374  -0.08320865  16.94379234]
#  [ -1.13358235   8.14983368  17.23496246  -5.3418293    4.06158257]
#  [ -1.33746004   7.78314877  24.43286133  -3.67889071   8.61840248]
#  [ -1.08984447   8.20415688  15.78243446  -5.65272236   3.16291666]]
# grad_b2
# [ -13.98910713   76.59251404  266.97677612  -31.39924049  100.59618378]
# grad_w3
# [[  0.67743206  -0.94054222   0.22873965  81.48891449   1.93386793
#     0.56291729   0.81267691]
#  [  0.69383299  -0.89653915   0.14031845  55.43406677   2.60273743
#     1.1794554    1.68486345]
#  [ -0.57625115   0.59430897   0.09121117  12.01309109  -3.54656553
#    -2.28015661  -3.26665139]
#  [  0.40029252  -0.61861515   0.22094819  69.47641754   0.59867013
#    -0.18383442  -0.25594518]
#  [  0.43301985  -0.67547143   0.25226033  84.33378601   0.55718648
#    -0.32614186  -0.43089089]]
# grad_b3
# [  2.68000174e+00  -4.04887533e+00   1.34880638e+00   4.29740875e+02
#    4.81083632e+00  -4.20391440e-01  -5.92206001e-01]

# %%
lRate = 1

inSize = 300.
grad_ins = np.expand_dims((np.arange(inSize)/inSize), 1) #get input 0-1
#grad_ins = np.expand_dims(np.arange(inSize), 1)

#np_grad1 =  np.tanh( np.dot(grad_ins, d['grad_w1']*lRate) + d['grad_b1']*lRate)
#np_grad2 =  np.tanh( np.dot(np_grad1, d['grad_w2']*lRate) + d['grad_b2']*lRate)
#np_grad3 =  np.tanh( np.dot(np_grad2, d['grad_w3']*lRate) + d['grad_b3']*lRate)

np_grad1 =  np.dot(grad_ins, d['grad_w1']*lRate) + d['grad_b1']*lRate
np_grad2 =  np.dot(np_grad1, d['grad_w2']*lRate) + d['grad_b2']*lRate
np_grad3 =  np.dot(np_grad2, d['grad_w3']*lRate) + d['grad_b3']*lRate

#print np_grad3
plt.plot(grad_ins, np_grad3)
# Out:
# <img src="data:image/png;base64,...">
# [<matplotlib.lines.Line2D at 0x10ac26fd0>,
#  <matplotlib.lines.Line2D at 0x10ac2a1d0>,
#  <matplotlib.lines.Line2D at 0x10ac2a310>,
#  <matplotlib.lines.Line2D at 0x10ac2a450>,
#  <matplotlib.lines.Line2D at 0x10ac2a590>,
#  <matplotlib.lines.Line2D at 0x10ac2a6d0>,
#  <matplotlib.lines.Line2D at 0x10ac2a810>]

# %%
s = 200  # sample index for testing

# %%
# %%capture
print 'netIn:'
print d['netIn'][s]

small_change = d['netIn'][s] + 0.05
print 'small_change:'
print small_change

# %%
# %%capture
print 'w1:'
print d['w1']
print 'b1:'
print d['b1']
print 'lay1:'
print d['lay1'][s]


np_calc1 =  np.tanh( np.dot(d['netIn'][s], d['w1']) + d['b1'])
np_dif1 =  np_calc1 - d['lay1'][s]

print 'numpy calc:'
print np_calc1
print 'numpy calc dif:'
print np_dif1

print '------------------------------'
np_calc_sc1 = np.tanh( np.dot(small_change, d['w1']) + d['b1'])
np_dif_sc1 = np_calc1 - np_calc_sc1

print 'numpy calc:'
print np_calc1
print 'numpy calc of small change:'
print np_calc_sc1
print 'numpy calc dif with small change:'
print np_dif_sc1
print '------------------------------'

# %%
# %%capture
print 'w2:'
print d['w2']
print 'b2:'
print d['b2']
print 'lay2:'
print d['lay2'][s]


np_calc2 =  np.tanh( np.dot(np_calc1, d['w2']) + d['b2'])
np_dif2 =  np_calc2 - d['lay2'][s]

print 'numpy calc:'
print np_calc2
print 'numpy calc dif:'
print np_dif2

# %%
# %%capture
print 'w3:'
print d['w3']
print 'b3:'
print d['b3']
print 'netOut:'
print d['netOut'][s]


np_calc3 =  np.tanh( np.dot(np_calc2, d['w3']) + d['b3'])
np_dif3 =  np_calc3 - d['netOut'][s]

print 'numpy calc:'
print np_calc3
print 'numpy calc dif:'
print np_dif3
